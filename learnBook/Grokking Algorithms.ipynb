# %% [markdown]
# #所有笔记来自于对《Grokking Algorithms》本书的摘录。
#
# 1.1引言
# 算法是一组完成任务的指令。任何代码片段都可视为算法。
#
# 1.4小结
# #二分查找是一种算法，输入是一个有序的元素列表。
# #二分查找的速度比简单查找快得多。
# #O(log n)比O(n)快。需要搜索的元素越多，前者比后者就快得越多。
# #算法运行时间并不以秒为单位。
# #算法运行时间是从其增速的角度度量的。
# #算法运行时间用大O表示法表示。
#
# 2.4小结
# #计算机内存犹如一大堆抽屉。
# #需要储存多个元素时，可使用数据或链表。
# #数组的元素都在一起。
# #链表的元素是分开的，其中每个元素都储存了下一个元素的地址。
# #数组的读取速度很快。
# #链表的插入和删除速度很快。
# #元素的位置被称为索引。
# #在同一个数组中，所有元素的类型都必须相同（都为int、double等）。
#
# 3.4小结
# #递归指的是调用自己的函数。
# #每个递归函数都有两个条件：基线条件和递归条件。
# #栈有两种操作：压入和弹出。
# #所有函数调用都进入调用栈。
# #调用栈可能很长，这将占用大量的内存。
#
# 4.4小结
# #D&C将问题逐步分解，使用D&C处理列表时，基线条件很可能是空数组或者包含一个元素的数组。
# #实现快速排序时，请随机地选择用作基准值的元素。快速排序的平均运行时间为O(n logn)。
# #大O表示法中的常量有时候事关重大，这就是快速排序比合并排序快的原因所在。
# #比较简单查找和二分查找时，常量几乎无关紧要，因为列表很长时，O(logn)的速度比O(n)快得多。
#
# 5.5小结
# 你几乎根本不用自己去实现散列表，因为你使用的编程语言提供了散列表实现。你可使用python提供的散列表，并假定能够获得平均情况下的性能：常量时间。
# 散列表是一种功能强大的数据结构，其操作速度快，还能让你以不同的方式建立数据模型。你可能很快会发现自己经常在使用它。
# #你可以结合散列函数和数组来创建散列表。
# #冲突很糟糕，你应使用可以最大限度减少冲突的散列函数。
# #散列表的查找、插入和删除速度都非常快。
# #散列表适合用于模拟映射关系。
# #一旦填装因子超过0.7，就该调整散列表的长度。
# #散列表可用于缓存数据（例如，在web服务器上）。
# #散列表非常适合用于防止重复。
#
# 6.5实现算法
# #在python中，可使用函数deque来创建一个双端队列。
#
# 6.6小结
# #广度优先搜索指出是否有从A到B的路径。如果有，广度优先搜索将找出最短路径。
# #面临类似于寻找最短路径的问题时，可尝试使用图来建立模型，再使用广度优先搜索来解决问题。
# #有向图中的边为箭头，箭头的方向指定了关系的方向，例如，rama→adit表示rama欠adit钱。
# #无向图中的边不带箭头，其中的关系是双向的，例如，ross—rachel表示“ross与rachel约会，而rachel也与ross约会”。
# #队列是先进先出(FIFO)的。
# #栈是后进先出(LIFO)的。
# #你需要按加入顺序检查搜索列表中的人，否则找到的就不是最短路径，因此搜索列表必须是队列。
# #对于检查过的人，务必不要再去检查，否则可能导致无限循环。
#
# 7.6小结
# #广度优先搜索用于在非加权图中查找最短路径。
# #狄克斯特拉算法用于在加权图中查找最短路径。
# #仅当权重为正时狄克斯特拉算法才管用。
# #如果图中包含负权边，请使用贝尔曼-福德算法。
#
# 8.5小结
# #贪婪算法寻找局部最优解，企图以这种方式获得全局最优解。
# #对于NP完全问题，还没有找到快速解决方案，最佳的做法时使用近似算法。
# #贪婪算法易于实现、运行速度快，是不错的近似算法。
#
# 9.4小结
# #需要在给定约束条件下优化某种指标时，动态规划很有用。
# #问题可分解为离散子问题时，可使用动态规划来解决。
# #某种动态规划解决方案都涉及网格。
# #单元格中的值通常就是你要优化的值。
# #每一个单元格都是一个子问题，因此你需要考虑如何将问题分解为子问题。
# #没有四海之内皆准的计算动态规划解决方案的公式。
#
# 10.4小结
# #KNN用于分类和回归，需要考虑最近的邻居。
# #分类就是编组。
# #回归就是预测结果（如数字）。
# #特征抽取意味着将物品（如水果或用户）转换为一系列可比较的数字。
# #能否挑选合适的特征事关KNN算法的成败。
#
# 11.1树
# #二叉查找树的数据结构用于将新的元素插入到数组的正确位置以方便检索。
# #对于二叉树的每一个节点，左子节点的值都比它小，而右子节点的值都比它大。
# #有一些处于平衡状态的特殊二叉查找树，如红黑树。
# #B树是一种特殊的二叉树，数据库常用它来储存数据。
# #相关概念：B树，红黑树，堆，伸展树。
#
# 11.2反向索引
# #一个散列表，将其单词映射到包含它的页面。这种数据结构被称为反向索引(inverted index)，常用于创建搜索引擎。
#
# 11.3傅里叶变换
#
# 11.4并行算法
# #为提高算法的速度，让它们在多个内核中并行地执行。
#
# 11.5MapReduce
# #分布式算法可让算法在多台计算机上运行以使用数百个内核。
# #MapReduce是一种流行的分布式算法，你可以通过流行的开源工具Apache Hadoop来使用它。
# #分布式算法非常适合用于在短时间内完成海量工作，其中的MapReduce基于两个简单的理念：映射(map)和归并(reduce)函数。
# #映射函数：它接受一个数组，并对其中的每个元素执行同样的处理。将一个数组转换为另一个数组。
# #归并函数：将很多项归并为一项。
#
# 11.6布隆过滤器和HyperLogLog
# #给定一个元素，需要快速判断它是否包含在这个集合中。为快速做出这种判断，可使用散列表。
# #布隆过滤器提供了解决之道，布隆过滤器是一种概率型数据结构，它提供的答案很可能是正确的（可能不对）。
# #布隆过滤器可能出现错报，但不可能出现漏报。（有可能没有，但没有一定没有）
# #HyperLogLog近似地计算集合中不同的元素数，是一种类布隆过滤器的算法，而占用的内存空间很少。
#
# 11.7 SHA算法
# #散列函数确定value应该放在数组的什么地方。
# #安全散列函数(secure hash algorithm, SHA)函数。给定一个字符串，SHA返回其散列值。
# #SHA用于比较文件，比较密码。可以通过这种算法根据字符串计算出散列值，而无法根据散列值推断出原始字符串。
# #当前，最安全的密码散列函数时bcrypt，但没有任何东西是万无一失的。
#
# 11.8局部敏感的散列算法
# #SHA是局部不敏感的，如果修改字符串中的一个字符，其散列值将截然不同。
# #Simhash是局部敏感的，如果只对字符串做细微的修改，生成的散列值也只存在细微的差别。
# #Simhash用于判断两个字符串的相似程度。
#
# 11.9 Diffie-Hellman密钥交换
# #Diiffie-Hellman使用两个密钥：公钥和私钥。
# #DH和替代者RSA都属于加密算法，当然，现在有许多。
#
# 11.1线性规划
# #线性规划用于在给定约束条件下最大程度地改善指定的指标
# #线性规划使用Simplex算法。
